# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import gi

# %%
# Tạo một mảng giá trị từ 0 đến 100
data = np.random.randint(0, 100, size=(10, 10))
# Tạo một hình ảnh từ dữ liệu   
sns.heatmap(data, annot=True, fmt="d", cmap="coolwarm", cbar=True)
# Tùy chỉnh tiêu đề và nhãn trục  
plt.xlabel("")
plt.ylabel("")


# Hiển thị hình ảnh
plt.tight_layout()
